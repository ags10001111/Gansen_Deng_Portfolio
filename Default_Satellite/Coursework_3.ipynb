# %% [markdown]
# Link to the notebook: https://colab.research.google.com/drive/1qPxV3BqCBKopvnGk2iH1YdN-3kTgvEoO?usp=sharing

# %%
# Download the file to drive
# !gdown 'https://drive.google.com/uc?id=1k7QmTjzk4hFrAnO_x8YvndoWyZ2H_LZw'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1k7QmTjzk4hFrAnO_x8YvndoWyZ2H_LZw
# To: /content/DataC3FM95282020.zip
# 2.59GB [00:36, 70.0MB/s]

# %%
# Unzip the file
# !unzip DataC3FM95282020.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#  extracting: Data/test/1/tile9_Area732_Q3.jpg
#  extracting: Data/test/1/tile9_Area734_Q3.jpg
#   inflating: Data/test/1/tile9_Area746_Q3.jpg
#  extracting: Data/test/1/tile9_Area752_Q3.jpg
#  extracting: Data/test/1/tile9_Area753_Q3.jpg
#  extracting: Data/test/1/tile9_Area759_Q3.jpg
#   inflating: Data/test/1/tile9_Area761_Q3.jpg
#  extracting: Data/test/1/tile9_Area762_Q3.jpg
#   inflating: Data/test/1/tile9_Area767_Q3.jpg
#   inflating: Data/test/1/tile9_Area76_Q3.jpg
#  extracting: Data/test/1/tile9_Area777_Q3.jpg
#  extracting: Data/test/1/tile9_Area780_Q3.jpg
#   inflating: Data/test/1/tile9_Area791_Q3.jpg
#    creating: Data/train/
#    creating: Data/train/0/
#  extracting: Data/train/0/tile10_Area106_Q3.jpg
#  extracting: Data/train/0/tile10_Area10_Q3.jpg
#  extracting: Data/train/0/tile10_Area110_Q3.jpg
#  extracting: Data/train/0/tile10_Area115_Q3.jpg
#  extracting: Data/train/0/tile10_Area119_Q3.jpg
#  extracting: Data/train/0/tile10_Area11_Q3.jpg
#  extracting: Data/train/0/tile10_Area120_Q3.jpg
#  extracting: Data/train/0/tile10_Area121_Q3.jpg
#   inflating: Data/train/0/tile10_Area122_Q3.jpg
#  extracting: Data/train/0/tile10_Area124_Q3.jpg
#  extracting: Data/train/0/tile10_Area131_Q3.jpg
#  extracting: Data/train/0/tile10_Area132_Q3.jpg
#  extracting: Data/train/0/tile10_Area133_Q3.jpg
#  extracting: Data/train/0/tile10_Area134_Q3.jpg
#  extracting: Data/train/0/tile10_Area137_Q3.jpg
#  extracting: Data/train/0/tile10_Area138_Q3.jpg
#  extracting: Data/train/0/tile10_Area144_Q3.jpg
#   inflating: Data/train/0/tile10_Area145_Q3.jpg
#  extracting: Data/train/0/tile10_Area146_Q3.jpg
#   inflating: Data/train/0/tile10_Area147_Q3.jpg
#  extracting: Data/train/0/tile10_Area149_Q3.jpg
#  extracting: Data/train/0/tile10_Area14_Q3.jpg
#  extracting: Data/train/0/tile10_Area154_Q3.jpg
#  extracting: Data/train/0/tile10_Area158_Q3.jpg
#  extracting: Data/train/0/tile10_Area160_Q3.jpg
#  extracting: Data/train/0/tile10_Area163_Q3.jpg
#  extracting: Data/train/0/tile10_Area167_Q3.jpg
#  extracting: Data/train/0/tile10_Area169_Q3.jpg
#  extracting: Data/train/0/tile10_Area16_Q3.jpg
#   inflating: Data/train/0/tile10_Area172_Q3.jpg
#  extracting: Data/train/0/tile10_Area175_Q3.jpg
#   inflating: Data/train/0/tile10_Area176_Q3.jpg
#  extracting: Data/train/0/tile10_Area177_Q3.jpg
#  extracting: Data/train/0/tile10_Area178_Q3.jpg
#  extracting: Data/train/0/tile10_Area182_Q3.jpg
#  extracting: Data/train/0/tile10_Area185_Q3.jpg
#  extracting: Data/train/0/tile10_Area188_Q3.jpg
#  extracting: Data/train/0/tile10_Area190_Q3.jpg
#  extracting: Data/train/0/tile10_Area193_Q3.jpg
#  extracting: Data/train/0/tile10_Area194_Q3.jpg
#  extracting: Data/train/0/tile10_Area195_Q3.jpg
#  extracting: Data/train/0/tile10_Area19_Q3.jpg
#  extracting: Data/train/0/tile10_Area202_Q3.jpg
#   inflating: Data/train/0/tile10_Area203_Q3.jpg
#  extracting: Data/train/0/tile10_Area208_Q3.jpg
#  extracting: Data/train/0/tile10_Area209_Q3.jpg
#  extracting: Data/train/0/tile10_Area20_Q3.jpg
#  extracting: Data/train/0/tile10_Area211_Q3.jpg
#  extracting: Data/train/0/tile10_Area214_Q3.jpg
#  extracting: Data/train/0/tile10_Area215_Q3.jpg
#   inflating: Data/train/0/tile10_Area216_Q3.jpg
#  extracting: Data/train/0/tile10_Area217_Q3.jpg
#   inflating: Data/train/0/tile10_Area221_Q3.jpg
#   inflating: Data/train/0/tile10_Area223_Q3.jpg
#  extracting: Data/train/0/tile10_Area227_Q3.jpg
#   inflating: Data/train/0/tile10_Area228_Q3.jpg
#  extracting: Data/train/0/tile10_Area229_Q3.jpg
#   inflating: Data/train/0/tile10_Area231_Q3.jpg
#  extracting: Data/train/0/tile10_Area232_Q3.jpg
#  extracting: Data/train/0/tile10_Area233_Q3.jpg
#  extracting: Data/train/0/tile10_Area235_Q3.jpg
#  extracting: Data/train/0/tile10_Area239_Q3.jpg
#  extracting: Data/train/0/tile10_Area241_Q3.jpg
#  extracting: Data/train/0/tile10_Area244_Q3.jpg
#  extracting: Data/train/0/tile10_Area246_Q3.jpg
#  extracting: Data/train/0/tile10_Area247_Q3.jpg
#  extracting: Data/train/0/tile10_Area24_Q3.jpg
#  extracting: Data/train/0/tile10_Area250_Q3.jpg
#  extracting: Data/train/0/tile10_Area253_Q3.jpg
#  extracting: Data/train/0/tile10_Area258_Q3.jpg
#  extracting: Data/train/0/tile10_Area25_Q3.jpg
#   inflating: Data/train/0/tile10_Area261_Q3.jpg
#   inflating: Data/train/0/tile10_Area265_Q3.jpg
#  extracting: Data/train/0/tile10_Area268_Q3.jpg
#  extracting: Data/train/0/tile10_Area269_Q3.jpg
#  extracting: Data/train/0/tile10_Area26_Q3.jpg
#  extracting: Data/train/0/tile10_Area271_Q3.jpg
#  extracting: Data/train/0/tile10_Area273_Q3.jpg
#   inflating: Data/train/0/tile10_Area275_Q3.jpg
#   inflating: Data/train/0/tile10_Area277_Q3.jpg
#  extracting: Data/train/0/tile10_Area279_Q3.jpg
#  extracting: Data/train/0/tile10_Area280_Q3.jpg
#  extracting: Data/train/0/tile10_Area284_Q3.jpg
#  extracting: Data/train/0/tile10_Area289_Q3.jpg
#  extracting: Data/train/0/tile10_Area28_Q3.jpg
#   inflating: Data/train/0/tile10_Area291_Q3.jpg
#  extracting: Data/train/0/tile10_Area292_Q3.jpg
#   inflating: Data/train/0/tile10_Area294_Q3.jpg
#  extracting: Data/train/0/tile10_Area295_Q3.jpg
#   inflating: Data/train/0/tile10_Area296_Q3.jpg
#  extracting: Data/train/0/tile10_Area298_Q3.jpg
#   inflating: Data/train/0/tile10_Area299_Q3.jpg
#  extracting: Data/train/0/tile10_Area29_Q3.jpg
#  extracting: Data/train/0/tile10_Area301_Q3.jpg
#   inflating: Data/train/0/tile10_Area302_Q3.jpg
#  extracting: Data/train/0/tile10_Area303_Q3.jpg
#   inflating: Data/train/0/tile10_Area307_Q3.jpg
#  extracting: Data/train/0/tile10_Area309_Q3.jpg
#  extracting: Data/train/0/tile10_Area314_Q3.jpg
#  extracting: Data/train/0/tile10_Area317_Q3.jpg
#  extracting: Data/train/0/tile10_Area318_Q3.jpg
#  extracting: Data/train/0/tile10_Area31_Q3.jpg
#  extracting: Data/train/0/tile10_Area323_Q3.jpg
#  extracting: Data/train/0/tile10_Area325_Q3.jpg
#  extracting: Data/train/0/tile10_Area326_Q3.jpg
#  extracting: Data/train/0/tile10_Area327_Q3.jpg
#  extracting: Data/train/0/tile10_Area330_Q3.jpg
#   inflating: Data/train/0/tile10_Area335_Q3.jpg
#  extracting: Data/train/0/tile10_Area336_Q3.jpg
#  extracting: Data/train/0/tile10_Area337_Q3.jpg
#  extracting: Data/train/0/tile10_Area338_Q3.jpg
#  extracting: Data/train/0/tile10_Area339_Q3.jpg
#  extracting: Data/train/0/tile10_Area33_Q3.jpg
#   inflating: Data/train/0/tile10_Area340_Q3.jpg
#  extracting: Data/train/0/tile10_Area341_Q3.jpg
#  extracting: Data/train/0/tile10_Area343_Q3.jpg
#  extracting: Data/train/0/tile10_Area344_Q3.jpg
#  extracting: Data/train/0/tile10_Area348_Q3.jpg
#  extracting: Data/train/0/tile10_Area34_Q3.jpg
#   inflating: Data/train/0/tile10_Area355_Q3.jpg
#   inflating: Data/train/0/tile10_Area361_Q3.jpg
#   inflating: Data/train/0/tile10_Area362_Q3.jpg
#  extracting: Data/train/0/tile10_Area364_Q3.jpg
#   inflating: Data/train/0/tile10_Area366_Q3.jpg
#  extracting: Data/train/0/tile10_Area367_Q3.jpg
#  extracting: Data/train/0/tile10_Area370_Q3.jpg
#  extracting: Data/train/0/tile10_Area372_Q3.jpg
#  extracting: Data/train/0/tile10_Area373_Q3.jpg
#  extracting: Data/train/0/tile10_Area375_Q3.jpg
#  extracting: Data/train/0/tile10_Area377_Q3.jpg
#  extracting: Data/train/0/tile10_Area380_Q3.jpg
#   inflating: Data/train/0/tile10_Area381_Q3.jpg
#  extracting: Data/train/0/tile10_Area383_Q3.jpg
#   inflating: Data/train/0/tile10_Area385_Q3.jpg
#  extracting: Data/train/0/tile10_Area386_Q3.jpg
#  extracting: Data/train/0/tile10_Area390_Q3.jpg
#   inflating: Data/train/0/tile10_Area396_Q3.jpg
#  extracting: Data/train/0/tile10_Area397_Q3.jpg
#  extracting: Data/train/0/tile10_Area399_Q3.jpg
#  extracting: Data/train/0/tile10_Area39_Q3.jpg
#  extracting: Data/train/0/tile10_Area400_Q3.jpg
#  extracting: Data/train/0/tile10_Area402_Q3.jpg
#  extracting: Data/train/0/tile10_Area403_Q3.jpg
#  extracting: Data/train/0/tile10_Area404_Q3.jpg
#  extracting: Data/train/0/tile10_Area405_Q3.jpg
#  extracting: Data/train/0/tile10_Area406_Q3.jpg
#   inflating: Data/train/0/tile10_Area407_Q3.jpg
#  extracting: Data/train/0/tile10_Area409_Q3.jpg
#  extracting: Data/train/0/tile10_Area410_Q3.jpg
#   inflating: Data/train/0/tile10_Area411_Q3.jpg
#   inflating: Data/train/0/tile10_Area413_Q3.jpg
#  extracting: Data/train/0/tile10_Area414_Q3.jpg
#   inflating: Data/train/0/tile10_Area415_Q3.jpg
#   inflating: Data/train/0/tile10_Area416_Q3.jpg
#  extracting: Data/train/0/tile10_Area417_Q3.jpg
#  extracting: Data/train/0/tile10_Area418_Q3.jpg
#  extracting: Data/train/0/tile10_Area421_Q3.jpg
#  extracting: Data/train/0/tile10_Area423_Q3.jpg
#  extracting: Data/train/0/tile10_Area427_Q3.jpg
#  extracting: Data/train/0/tile10_Area428_Q3.jpg
#  extracting: Data/train/0/tile10_Area42_Q3.jpg
#  extracting: Data/train/0/tile10_Area430_Q3.jpg
#  extracting: Data/train/0/tile10_Area431_Q3.jpg
#  extracting: Data/train/0/tile10_Area432_Q3.jpg
#   inflating: Data/train/0/tile10_Area433_Q3.jpg
#  extracting: Data/train/0/tile10_Area435_Q3.jpg
#  extracting: Data/train/0/tile10_Area436_Q3.jpg
#  extracting: Data/train/0/tile10_Area437_Q3.jpg
#  extracting: Data/train/0/tile10_Area438_Q3.jpg
#  extracting: Data/train/0/tile10_Area440_Q3.jpg
#   inflating: Data/train/0/tile10_Area444_Q3.jpg
#  extracting: Data/train/0/tile10_Area447_Q3.jpg
#  extracting: Data/train/0/tile10_Area449_Q3.jpg
#  extracting: Data/train/0/tile10_Area451_Q3.jpg
#   inflating: Data/train/0/tile10_Area453_Q3.jpg
#   inflating: Data/train/0/tile10_Area454_Q3.jpg
#   inflating: Data/train/0/tile10_Area457_Q3.jpg
#  extracting: Data/train/0/tile10_Area462_Q3.jpg
#  extracting: Data/train/0/tile10_Area464_Q3.jpg
#  extracting: Data/train/0/tile10_Area466_Q3.jpg
#  extracting: Data/train/0/tile10_Area468_Q3.jpg
#  extracting: Data/train/0/tile10_Area46_Q3.jpg
#  extracting: Data/train/0/tile10_Area470_Q3.jpg
#  extracting: Data/train/0/tile10_Area473_Q3.jpg
#   inflating: Data/train/0/tile10_Area476_Q3.jpg
#  extracting: Data/train/0/tile10_Area483_Q3.jpg
#  extracting: Data/train/0/tile10_Area486_Q3.jpg
#   inflating: Data/train/0/tile10_Area488_Q3.jpg
#  extracting: Data/train/0/tile10_Area489_Q3.jpg
#   inflating: Data/train/0/tile10_Area491_Q3.jpg
#  extracting: Data/train/0/tile10_Area495_Q3.jpg
#  extracting: Data/train/0/tile10_Area497_Q3.jpg
#  extracting: Data/train/0/tile10_Area4_Q3.jpg
#  extracting: Data/train/0/tile10_Area500_Q3.jpg
#   inflating: Data/train/0/tile10_Area502_Q3.jpg
#  extracting: Data/train/0/tile10_Area506_Q3.jpg
#   inflating: Data/train/0/tile10_Area508_Q3.jpg
#  extracting: Data/train/0/tile10_Area509_Q3.jpg
#  extracting: Data/train/0/tile10_Area510_Q3.jpg
#   inflating: Data/train/0/tile10_Area512_Q3.jpg
#  extracting: Data/train/0/tile10_Area515_Q3.jpg
#   inflating: Data/train/0/tile10_Area517_Q3.jpg
#  extracting: Data/train/0/tile10_Area519_Q3.jpg
#  extracting: Data/train/0/tile10_Area521_Q3.jpg
#  extracting: Data/train/0/tile10_Area522_Q3.jpg
#   inflating: Data/train/0/tile10_Area524_Q3.jpg
#  extracting: Data/train/0/tile10_Area526_Q3.jpg
#  extracting: Data/train/0/tile10_Area529_Q3.jpg
#  extracting: Data/train/0/tile10_Area533_Q3.jpg
#  extracting: Data/train/0/tile10_Area535_Q3.jpg
#   inflating: Data/train/0/tile10_Area536_Q3.jpg
#  extracting: Data/train/0/tile10_Area538_Q3.jpg
#  extracting: Data/train/0/tile10_Area539_Q3.jpg
#  extracting: Data/train/0/tile10_Area53_Q3.jpg
#   inflating: Data/train/0/tile10_Area540_Q3.jpg
#  extracting: Data/train/0/tile10_Area541_Q3.jpg
#  extracting: Data/train/0/tile10_Area543_Q3.jpg
#  extracting: Data/train/0/tile10_Area544_Q3.jpg
#   inflating: Data/train/0/tile10_Area545_Q3.jpg
#   inflating: Data/train/0/tile10_Area547_Q3.jpg
#   inflating: Data/train/0/tile10_Area549_Q3.jpg
#  extracting: Data/train/0/tile10_Area54_Q3.jpg
#  extracting: Data/train/0/tile10_Area550_Q3.jpg
#  extracting: Data/train/0/tile10_Area551_Q3.jpg
#   inflating: Data/train/0/tile10_Area556_Q3.jpg
#  extracting: Data/train/0/tile10_Area560_Q3.jpg
#  extracting: Data/train/0/tile10_Area573_Q3.jpg
#  extracting: Data/train/0/tile10_Area574_Q3.jpg
#  extracting: Data/train/0/tile10_Area575_Q3.jpg
#  extracting: Data/train/0/tile10_Area578_Q3.jpg
#  extracting: Data/train/0/tile10_Area57_Q3.jpg
#   inflating: Data/train/0/tile10_Area581_Q3.jpg
#  extracting: Data/train/0/tile10_Area582_Q3.jpg
#  extracting: Data/train/0/tile10_Area586_Q3.jpg
#   inflating: Data/train/0/tile10_Area587_Q3.jpg
#  extracting: Data/train/0/tile10_Area588_Q3.jpg
#  extracting: Data/train/0/tile10_Area58_Q3.jpg
#  extracting: Data/train/0/tile10_Area593_Q3.jpg
#  extracting: Data/train/0/tile10_Area594_Q3.jpg
#   inflating: Data/train/0/tile10_Area595_Q3.jpg
#  extracting: Data/train/0/tile10_Area596_Q3.jpg
#  extracting: Data/train/0/tile10_Area597_Q3.jpg
#  extracting: Data/train/0/tile10_Area59_Q3.jpg
#   inflating: Data/train/0/tile10_Area604_Q3.jpg
#  extracting: Data/train/0/tile10_Area605_Q3.jpg
#  extracting: Data/train/0/tile10_Area609_Q3.jpg
#  extracting: Data/train/0/tile10_Area611_Q3.jpg
#  extracting: Data/train/0/tile10_Area614_Q3.jpg
#  extracting: Data/train/0/tile10_Area617_Q3.jpg
#  extracting: Data/train/0/tile10_Area619_Q3.jpg
#  extracting: Data/train/0/tile10_Area620_Q3.jpg
#  extracting: Data/train/0/tile10_Area621_Q3.jpg
#  extracting: Data/train/0/tile10_Area623_Q3.jpg
#  extracting: Data/train/0/tile10_Area624_Q3.jpg
#  extracting: Data/train/0/tile10_Area626_Q3.jpg
#   inflating: Data/train/0/tile10_Area627_Q3.jpg
#   inflating: Data/train/0/tile10_Area629_Q3.jpg
#  extracting: Data/train/0/tile10_Area632_Q3.jpg
#  extracting: Data/train/0/tile10_Area635_Q3.jpg
#  extracting: Data/train/0/tile10_Area637_Q3.jpg
#  extracting: Data/train/0/tile10_Area638_Q3.jpg
#  extracting: Data/train/0/tile10_Area639_Q3.jpg
#   inflating: Data/train/0/tile10_Area63_Q3.jpg
#  extracting: Data/train/0/tile10_Area640_Q3.jpg
#  extracting: Data/train/0/tile10_Area644_Q3.jpg
#   inflating: Data/train/0/tile10_Area648_Q3.jpg
#  extracting: Data/train/0/tile10_Area64_Q3.jpg
#  extracting: Data/train/0/tile10_Area658_Q3.jpg
#   inflating: Data/train/0/tile10_Area659_Q3.jpg
#  extracting: Data/train/0/tile10_Area660_Q3.jpg
#   inflating: Data/train/0/tile10_Area661_Q3.jpg
#   inflating: Data/train/0/tile10_Area663_Q3.jpg
#   inflating: Data/train/0/tile10_Area665_Q3.jpg
#   inflating: Data/train/0/tile10_Area667_Q3.jpg
#  extracting: Data/train/0/tile10_Area669_Q3.jpg
#  extracting: Data/train/0/tile10_Area66_Q3.jpg
#   inflating: Data/train/0/tile10_Area672_Q3.jpg
#  extracting: Data/train/0/tile10_Area679_Q3.jpg
#   inflating: Data/train/0/tile10_Area681_Q3.jpg
#  extracting: Data/train/0/tile10_Area683_Q3.jpg
#  extracting: Data/train/0/tile10_Area684_Q3.jpg
#  extracting: Data/train/0/tile10_Area689_Q3.jpg
#  extracting: Data/train/0/tile10_Area68_Q3.jpg
#  extracting: Data/train/0/tile10_Area690_Q3.jpg
#   inflating: Data/train/0/tile10_Area694_Q3.jpg
#  extracting: Data/train/0/tile10_Area698_Q3.jpg
#   inflating: Data/train/0/tile10_Area699_Q3.jpg
#  extracting: Data/train/0/tile10_Area69_Q3.jpg
#   inflating: Data/train/0/tile10_Area702_Q3.jpg
#  extracting: Data/train/0/tile10_Area705_Q3.jpg
#  extracting: Data/train/0/tile10_Area706_Q3.jpg
#  extracting: Data/train/0/tile10_Area707_Q3.jpg
#   inflating: Data/train/0/tile10_Area708_Q3.jpg
#  extracting: Data/train/0/tile10_Area709_Q3.jpg
#  extracting: Data/train/0/tile10_Area70_Q3.jpg
#  extracting: Data/train/0/tile10_Area710_Q3.jpg
#  extracting: Data/train/0/tile10_Area711_Q3.jpg
#  extracting: Data/train/0/tile10_Area714_Q3.jpg
#  extracting: Data/train/0/tile10_Area715_Q3.jpg
#  extracting: Data/train/0/tile10_Area716_Q3.jpg
#   inflating: Data/train/0/tile10_Area717_Q3.jpg
#  extracting: Data/train/0/tile10_Area718_Q3.jpg
#   inflating: Data/train/0/tile10_Area719_Q3.jpg
#  extracting: Data/train/0/tile10_Area71_Q3.jpg
#   inflating: Data/train/0/tile10_Area724_Q3.jpg
#   inflating: Data/train/0/tile10_Area729_Q3.jpg
#   inflating: Data/train/0/tile10_Area730_Q3.jpg
#   inflating: Data/train/0/tile10_Area735_Q3.jpg
#  extracting: Data/train/0/tile10_Area738_Q3.jpg
#  extracting: Data/train/0/tile10_Area739_Q3.jpg
#   inflating: Data/train/0/tile10_Area73_Q3.jpg
#  extracting: Data/train/0/tile10_Area748_Q3.jpg
#  extracting: Data/train/0/tile10_Area749_Q3.jpg
#  extracting: Data/train/0/tile10_Area754_Q3.jpg
#  extracting: Data/train/0/tile10_Area756_Q3.jpg
#  extracting: Data/train/0/tile10_Area758_Q3.jpg
#  extracting: Data/train/0/tile10_Area75_Q3.jpg
#  extracting: Data/train/0/tile10_Area764_Q3.jpg
#  extracting: Data/train/0/tile10_Area768_Q3.jpg
#  extracting: Data/train/0/tile10_Area769_Q3.jpg
#  extracting: Data/train/0/tile10_Area771_Q3.jpg
#  extracting: Data/train/0/tile10_Area772_Q3.jpg
#   inflating: Data/train/0/tile10_Area775_Q3.jpg
#   inflating: Data/train/0/tile10_Area781_Q3.jpg
#  extracting: Data/train/0/tile10_Area784_Q3.jpg
#   inflating: Data/train/0/tile10_Area785_Q3.jpg
#  extracting: Data/train/0/tile10_Area788_Q3.jpg
#   inflating: Data/train/0/tile10_Area792_Q3.jpg
#  extracting: Data/train/0/tile10_Area793_Q3.jpg
#  extracting: Data/train/0/tile10_Area794_Q3.jpg
#  extracting: Data/train/0/tile10_Area795_Q3.jpg
#  extracting: Data/train/0/tile10_Area796_Q3.jpg
#   inflating: Data/train/0/tile10_Area797_Q3.jpg
#  extracting: Data/train/0/tile10_Area798_Q3.jpg
#  extracting: Data/train/0/tile10_Area799_Q3.jpg
#  extracting: Data/train/0/tile10_Area79_Q3.jpg
#   inflating: Data/train/0/tile10_Area7_Q3.jpg
#  extracting: Data/train/0/tile10_Area800_Q3.jpg
#   inflating: Data/train/0/tile10_Area801_Q3.jpg
#  extracting: Data/train/0/tile10_Area803_Q3.jpg
#  extracting: Data/train/0/tile10_Area80_Q3.jpg
#  extracting: Data/train/0/tile10_Area81_Q3.jpg
#  extracting: Data/train/0/tile10_Area82_Q3.jpg
#  extracting: Data/train/0/tile10_Area86_Q3.jpg
#  extracting: Data/train/0/tile10_Area89_Q3.jpg
#  extracting: Data/train/0/tile10_Area90_Q3.jpg
#   inflating: Data/train/0/tile10_Area93_Q3.jpg
#  extracting: Data/train/0/tile10_Area95_Q3.jpg
#  extracting: Data/train/0/tile10_Area97_Q3.jpg
#   inflating: Data/train/0/tile10_Area99_Q3.jpg
#   inflating: Data/train/0/tile10_Area9_Q3.jpg
#  extracting: Data/train/0/tile11_Area106_Q3.jpg
#  extracting: Data/train/0/tile11_Area10_Q3.jpg
#  extracting: Data/train/0/tile11_Area110_Q3.jpg
#  extracting: Data/train/0/tile11_Area115_Q3.jpg
#  extracting: Data/train/0/tile11_Area119_Q3.jpg
#  extracting: Data/train/0/tile11_Area11_Q3.jpg
#  extracting: Data/train/0/tile11_Area120_Q3.jpg
#   inflating: Data/train/0/tile11_Area121_Q3.jpg
#  extracting: Data/train/0/tile11_Area122_Q3.jpg
#  extracting: Data/train/0/tile11_Area124_Q3.jpg
#  extracting: Data/train/0/tile11_Area131_Q3.jpg
#  extracting: Data/train/0/tile11_Area132_Q3.jpg
#  extracting: Data/train/0/tile11_Area133_Q3.jpg
#  extracting: Data/train/0/tile11_Area134_Q3.jpg
#  extracting: Data/train/0/tile11_Area137_Q3.jpg
#  extracting: Data/train/0/tile11_Area138_Q3.jpg
#  extracting: Data/train/0/tile11_Area144_Q3.jpg
#   inflating: Data/train/0/tile11_Area145_Q3.jpg
#  extracting: Data/train/0/tile11_Area146_Q3.jpg
#   inflating: Data/train/0/tile11_Area147_Q3.jpg
#  extracting: Data/train/0/tile11_Area149_Q3.jpg
#  extracting: Data/train/0/tile11_Area14_Q3.jpg
#  extracting: Data/train/0/tile11_Area154_Q3.jpg
#  extracting: Data/train/0/tile11_Area158_Q3.jpg
#  extracting: Data/train/0/tile11_Area160_Q3.jpg
#  extracting: Data/train/0/tile11_Area163_Q3.jpg
#  extracting: Data/train/0/tile11_Area167_Q3.jpg
#  extracting: Data/train/0/tile11_Area169_Q3.jpg
#  extracting: Data/train/0/tile11_Area16_Q3.jpg
#   inflating: Data/train/0/tile11_Area172_Q3.jpg
#  extracting: Data/train/0/tile11_Area175_Q3.jpg
#   inflating: Data/train/0/tile11_Area176_Q3.jpg
#  extracting: Data/train/0/tile11_Area177_Q3.jpg
#   inflating: Data/train/0/tile11_Area178_Q3.jpg
#  extracting: Data/train/0/tile11_Area182_Q3.jpg
#  extracting: Data/train/0/tile11_Area185_Q3.jpg
#  extracting: Data/train/0/tile11_Area188_Q3.jpg
#  extracting: Data/train/0/tile11_Area190_Q3.jpg
#  extracting: Data/train/0/tile11_Area193_Q3.jpg
#  extracting: Data/train/0/tile11_Area194_Q3.jpg
#  extracting: Data/train/0/tile11_Area195_Q3.jpg
#  extracting: Data/train/0/tile11_Area19_Q3.jpg
#  extracting: Data/train/0/tile11_Area202_Q3.jpg
#   inflating: Data/train/0/tile11_Area203_Q3.jpg
#  extracting: Data/train/0/tile11_Area208_Q3.jpg
#  extracting: Data/train/0/tile11_Area209_Q3.jpg
#  extracting: Data/train/0/tile11_Area20_Q3.jpg
#  extracting: Data/train/0/tile11_Area211_Q3.jpg
#  extracting: Data/train/0/tile11_Area214_Q3.jpg
#  extracting: Data/train/0/tile11_Area215_Q3.jpg
#   inflating: Data/train/0/tile11_Area216_Q3.jpg
#   inflating: Data/train/0/tile11_Area217_Q3.jpg
#  extracting: Data/train/0/tile11_Area764_Q3.jpg
#  extracting: Data/train/0/tile11_Area768_Q3.jpg
#   inflating: Data/train/0/tile11_Area769_Q3.jpg
#  extracting: Data/train/0/tile11_Area771_Q3.jpg
#  extracting: Data/train/0/tile11_Area772_Q3.jpg
#   inflating: Data/train/0/tile11_Area775_Q3.jpg
#   inflating: Data/train/0/tile11_Area781_Q3.jpg
#  extracting: Data/train/0/tile11_Area784_Q3.jpg
#   inflating: Data/train/0/tile11_Area785_Q3.jpg
#  extracting: Data/train/0/tile11_Area788_Q3.jpg
#   inflating: Data/train/0/tile11_Area792_Q3.jpg
#  extracting: Data/train/0/tile11_Area793_Q3.jpg
#  extracting: Data/train/0/tile11_Area794_Q3.jpg
#  extracting: Data/train/0/tile11_Area795_Q3.jpg
#  extracting: Data/train/0/tile11_Area796_Q3.jpg
#   inflating: Data/train/0/tile11_Area797_Q3.jpg
#  extracting: Data/train/0/tile11_Area798_Q3.jpg
#  extracting: Data/train/0/tile11_Area799_Q3.jpg
#   inflating: Data/train/0/tile11_Area79_Q3.jpg
#   inflating: Data/train/0/tile11_Area7_Q3.jpg
#  extracting: Data/train/0/tile11_Area800_Q3.jpg
#   inflating: Data/train/0/tile11_Area801_Q3.jpg
#  extracting: Data/train/0/tile11_Area803_Q3.jpg
#  extracting: Data/train/0/tile11_Area80_Q3.jpg
#  extracting: Data/train/0/tile11_Area81_Q3.jpg
#  extracting: Data/train/0/tile11_Area82_Q3.jpg
#  extracting: Data/train/0/tile11_Area86_Q3.jpg
#  extracting: Data/train/0/tile11_Area89_Q3.jpg
#  extracting: Data/train/0/tile11_Area90_Q3.jpg
#   inflating: Data/train/0/tile11_Area93_Q3.jpg
#  extracting: Data/train/0/tile11_Area95_Q3.jpg
#  extracting: Data/train/0/tile11_Area97_Q3.jpg
#   inflating: Data/train/0/tile11_Area99_Q3.jpg
#   inflating: Data/train/0/tile11_Area9_Q3.jpg
#  extracting: Data/train/0/tile12_Area106_Q3.jpg
#  extracting: Data/train/0/tile12_Area10_Q3.jpg
#  extracting: Data/train/0/tile12_Area110_Q3.jpg
#  extracting: Data/train/0/tile12_Area115_Q3.jpg
#  extracting: Data/train/0/tile12_Area119_Q3.jpg
#  extracting: Data/train/0/tile12_Area11_Q3.jpg
#  extracting: Data/train/0/tile12_Area120_Q3.jpg
#  extracting: Data/train/0/tile12_Area121_Q3.jpg
#  extracting: Data/train/0/tile12_Area122_Q3.jpg
#  extracting: Data/train/0/tile12_Area124_Q3.jpg
#  extracting: Data/train/0/tile12_Area131_Q3.jpg
#  extracting: Data/train/0/tile12_Area132_Q3.jpg
#  extracting: Data/train/0/tile12_Area133_Q3.jpg
#  extracting: Data/train/0/tile12_Area134_Q3.jpg
#  extracting: Data/train/0/tile12_Area137_Q3.jpg
#  extracting: Data/train/0/tile12_Area138_Q3.jpg
#   inflating: Data/train/0/tile12_Area144_Q3.jpg
#   inflating: Data/train/0/tile12_Area145_Q3.jpg
#  extracting: Data/train/0/tile12_Area146_Q3.jpg
#   inflating: Data/train/0/tile12_Area147_Q3.jpg
#  extracting: Data/train/0/tile12_Area149_Q3.jpg
#  extracting: Data/train/0/tile12_Area14_Q3.jpg
#   inflating: Data/train/0/tile12_Area154_Q3.jpg
#  extracting: Data/train/0/tile12_Area158_Q3.jpg
#  extracting: Data/train/0/tile12_Area160_Q3.jpg
#  extracting: Data/train/0/tile12_Area163_Q3.jpg
#  extracting: Data/train/0/tile12_Area167_Q3.jpg
#  extracting: Data/train/0/tile12_Area169_Q3.jpg
#  extracting: Data/train/0/tile12_Area16_Q3.jpg
#   inflating: Data/train/0/tile12_Area172_Q3.jpg
#  extracting: Data/train/0/tile12_Area175_Q3.jpg
#   inflating: Data/train/0/tile12_Area176_Q3.jpg
#  extracting: Data/train/0/tile12_Area177_Q3.jpg
#   inflating: Data/train/0/tile12_Area178_Q3.jpg
#  extracting: Data/train/0/tile12_Area182_Q3.jpg
#  extracting: Data/train/0/tile12_Area185_Q3.jpg
#  extracting: Data/train/0/tile12_Area188_Q3.jpg
#  extracting: Data/train/0/tile12_Area190_Q3.jpg
#  extracting: Data/train/0/tile12_Area193_Q3.jpg
#  extracting: Data/train/0/tile12_Area194_Q3.jpg
#  extracting: Data/train/0/tile12_Area195_Q3.jpg
#  extracting: Data/train/0/tile12_Area19_Q3.jpg
#  extracting: Data/train/0/tile12_Area202_Q3.jpg
#   inflating: Data/train/0/tile12_Area203_Q3.jpg
#   inflating: Data/train/0/tile12_Area208_Q3.jpg
#  extracting: Data/train/0/tile12_Area209_Q3.jpg
#  extracting: Data/train/0/tile12_Area20_Q3.jpg
#  extracting: Data/train/0/tile12_Area211_Q3.jpg
#  extracting: Data/train/0/tile12_Area214_Q3.jpg
#  extracting: Data/train/0/tile12_Area215_Q3.jpg
#  extracting: Data/train/0/tile12_Area216_Q3.jpg
#   inflating: Data/train/0/tile12_Area217_Q3.jpg
#   inflating: Data/train/0/tile12_Area221_Q3.jpg
#   inflating: Data/train/0/tile12_Area223_Q3.jpg
#  extracting: Data/train/0/tile12_Area227_Q3.jpg
#   inflating: Data/train/0/tile12_Area228_Q3.jpg
#   inflating: Data/train/0/tile12_Area229_Q3.jpg
#  extracting: Data/train/0/tile12_Area231_Q3.jpg
#   inflating: Data/train/0/tile12_Area232_Q3.jpg
#  extracting: Data/train/0/tile12_Area233_Q3.jpg
#  extracting: Data/train/0/tile12_Area235_Q3.jpg
#   inflating: Data/train/0/tile12_Area239_Q3.jpg
#  extracting: Data/train/0/tile12_Area241_Q3.jpg
#  extracting: Data/train/0/tile12_Area244_Q3.jpg
#  extracting: Data/train/0/tile12_Area246_Q3.jpg
#   inflating: Data/train/0/tile12_Area247_Q3.jpg
#  extracting: Data/train/0/tile12_Area24_Q3.jpg
#   inflating: Data/train/0/tile12_Area250_Q3.jpg
#  extracting: Data/train/0/tile12_Area253_Q3.jpg
#  extracting: Data/train/0/tile12_Area258_Q3.jpg
#  extracting: Data/train/0/tile12_Area25_Q3.jpg
#   inflating: Data/train/0/tile12_Area261_Q3.jpg
#   inflating: Data/train/0/tile12_Area265_Q3.jpg
#  extracting: Data/train/0/tile12_Area268_Q3.jpg
#  extracting: Data/train/0/tile12_Area269_Q3.jpg
#  extracting: Data/train/0/tile12_Area26_Q3.jpg
#  extracting: Data/train/0/tile12_Area271_Q3.jpg
#   inflating: Data/train/0/tile12_Area273_Q3.jpg
#  extracting: Data/train/0/tile12_Area275_Q3.jpg
#  extracting: Data/train/0/tile12_Area277_Q3.jpg
#   inflating: Data/train/0/tile12_Area279_Q3.jpg
#  extracting: Data/train/0/tile12_Area280_Q3.jpg
#  extracting: Data/train/0/tile12_Area284_Q3.jpg
#  extracting: Data/train/0/tile12_Area289_Q3.jpg
#  extracting: Data/train/0/tile12_Area28_Q3.jpg
#  extracting: Data/train/0/tile12_Area291_Q3.jpg
#  extracting: Data/train/0/tile12_Area292_Q3.jpg
#  extracting: Data/train/0/tile12_Area294_Q3.jpg
#  extracting: Data/train/0/tile12_Area295_Q3.jpg
#   inflating: Data/train/0/tile12_Area296_Q3.jpg
#  extracting: Data/train/0/tile12_Area298_Q3.jpg
#   inflating: Data/train/0/tile12_Area299_Q3.jpg
#  extracting: Data/train/0/tile12_Area29_Q3.jpg
#  extracting: Data/train/0/tile12_Area301_Q3.jpg
#  extracting: Data/train/0/tile12_Area302_Q3.jpg
#  extracting: Data/train/0/tile12_Area303_Q3.jpg
#   inflating: Data/train/0/tile12_Area307_Q3.jpg
#   inflating: Data/train/0/tile12_Area309_Q3.jpg
#   inflating: Data/train/0/tile12_Area314_Q3.jpg
#  extracting: Data/train/0/tile12_Area317_Q3.jpg
#  extracting: Data/train/0/tile12_Area318_Q3.jpg
#  extracting: Data/train/0/tile12_Area31_Q3.jpg
#  extracting: Data/train/0/tile12_Area323_Q3.jpg
#  extracting: Data/train/0/tile12_Area325_Q3.jpg
#  extracting: Data/train/0/tile12_Area326_Q3.jpg
#  extracting: Data/train/0/tile12_Area327_Q3.jpg
#  extracting: Data/train/0/tile12_Area330_Q3.jpg
#  extracting: Data/train/0/tile12_Area335_Q3.jpg
#  extracting: Data/train/0/tile12_Area336_Q3.jpg
#  extracting: Data/train/0/tile12_Area337_Q3.jpg
#  extracting: Data/train/0/tile12_Area338_Q3.jpg
#  extracting: Data/train/0/tile12_Area339_Q3.jpg
#  extracting: Data/train/0/tile12_Area33_Q3.jpg
#  extracting: Data/train/0/tile12_Area340_Q3.jpg
#  extracting: Data/train/0/tile12_Area341_Q3.jpg
#  extracting: Data/train/0/tile12_Area343_Q3.jpg
#  extracting: Data/train/0/tile12_Area344_Q3.jpg
#   inflating: Data/train/0/tile12_Area348_Q3.jpg
#  extracting: Data/train/0/tile12_Area34_Q3.jpg
#   inflating: Data/train/0/tile12_Area355_Q3.jpg
#   inflating: Data/train/0/tile12_Area361_Q3.jpg
#  extracting: Data/train/0/tile12_Area362_Q3.jpg
#  extracting: Data/train/0/tile12_Area364_Q3.jpg
#  extracting: Data/train/0/tile12_Area366_Q3.jpg
#  extracting: Data/train/0/tile12_Area367_Q3.jpg
#  extracting: Data/train/0/tile12_Area370_Q3.jpg
#  extracting: Data/train/0/tile12_Area372_Q3.jpg
#  extracting: Data/train/0/tile12_Area373_Q3.jpg
#   inflating: Data/train/0/tile12_Area375_Q3.jpg
#  extracting: Data/train/0/tile12_Area377_Q3.jpg
#  extracting: Data/train/0/tile12_Area380_Q3.jpg
#   inflating: Data/train/0/tile12_Area381_Q3.jpg
#  extracting: Data/train/0/tile12_Area383_Q3.jpg
#  extracting: Data/train/0/tile12_Area385_Q3.jpg
#  extracting: Data/train/0/tile12_Area386_Q3.jpg
#  extracting: Data/train/0/tile12_Area390_Q3.jpg
#   inflating: Data/train/0/tile12_Area396_Q3.jpg
#  extracting: Data/train/0/tile12_Area397_Q3.jpg
#  extracting: Data/train/0/tile12_Area399_Q3.jpg
#  extracting: Data/train/0/tile12_Area39_Q3.jpg
#  extracting: Data/train/0/tile12_Area400_Q3.jpg
#  extracting: Data/train/0/tile12_Area402_Q3.jpg
#   inflating: Data/train/0/tile12_Area403_Q3.jpg
#  extracting: Data/train/0/tile12_Area404_Q3.jpg
#  extracting: Data/train/0/tile12_Area405_Q3.jpg
#  extracting: Data/train/0/tile12_Area406_Q3.jpg
#   inflating: Data/train/0/tile12_Area407_Q3.jpg
#  extracting: Data/train/0/tile12_Area409_Q3.jpg
#  extracting: Data/train/0/tile12_Area410_Q3.jpg
#   inflating: Data/train/0/tile12_Area411_Q3.jpg
#   inflating: Data/train/0/tile12_Area413_Q3.jpg
#  extracting: Data/train/0/tile12_Area414_Q3.jpg
#   inflating: Data/train/0/tile12_Area415_Q3.jpg
#   inflating: Data/train/0/tile12_Area416_Q3.jpg
#  extracting: Data/train/0/tile12_Area417_Q3.jpg
#  extracting: Data/train/0/tile12_Area418_Q3.jpg
#  extracting: Data/train/0/tile12_Area421_Q3.jpg
#  extracting: Data/train/0/tile12_Area423_Q3.jpg
#  extracting: Data/train/0/tile12_Area427_Q3.jpg
#  extracting: Data/train/0/tile12_Area428_Q3.jpg
#  extracting: Data/train/0/tile12_Area42_Q3.jpg
#  extracting: Data/train/0/tile12_Area430_Q3.jpg
#   inflating: Data/train/0/tile12_Area431_Q3.jpg
#   inflating: Data/train/0/tile12_Area432_Q3.jpg
#  extracting: Data/train/0/tile12_Area433_Q3.jpg
#  extracting: Data/train/0/tile12_Area435_Q3.jpg
#  extracting: Data/train/0/tile12_Area436_Q3.jpg
#  extracting: Data/train/0/tile12_Area437_Q3.jpg
#  extracting: Data/train/0/tile12_Area438_Q3.jpg
#  extracting: Data/train/0/tile12_Area440_Q3.jpg
#   inflating: Data/train/0/tile12_Area444_Q3.jpg
#  extracting: Data/train/0/tile12_Area447_Q3.jpg
#   inflating: Data/train/0/tile12_Area449_Q3.jpg
#  extracting: Data/train/0/tile12_Area451_Q3.jpg
#   inflating: Data/train/0/tile12_Area453_Q3.jpg
#   inflating: Data/train/0/tile12_Area454_Q3.jpg
#   inflating: Data/train/0/tile12_Area457_Q3.jpg
#  extracting: Data/train/0/tile12_Area462_Q3.jpg
#  extracting: Data/train/0/tile12_Area464_Q3.jpg
#  extracting: Data/train/0/tile12_Area466_Q3.jpg
#  extracting: Data/train/0/tile12_Area468_Q3.jpg
#  extracting: Data/train/0/tile12_Area46_Q3.jpg
#  extracting: Data/train/0/tile12_Area470_Q3.jpg
#  extracting: Data/train/0/tile12_Area473_Q3.jpg
#  extracting: Data/train/0/tile12_Area476_Q3.jpg
#  extracting: Data/train/0/tile12_Area483_Q3.jpg
#  extracting: Data/train/0/tile12_Area486_Q3.jpg
#  extracting: Data/train/0/tile12_Area488_Q3.jpg
#  extracting: Data/train/0/tile12_Area489_Q3.jpg
#   inflating: Data/train/0/tile12_Area491_Q3.jpg
#  extracting: Data/train/0/tile12_Area495_Q3.jpg
#  extracting: Data/train/0/tile12_Area497_Q3.jpg
#  extracting: Data/train/0/tile12_Area4_Q3.jpg
#  extracting: Data/train/0/tile12_Area500_Q3.jpg
#  extracting: Data/train/0/tile12_Area502_Q3.jpg
#  extracting: Data/train/0/tile12_Area506_Q3.jpg
#  extracting: Data/train/0/tile12_Area508_Q3.jpg
#  extracting: Data/train/0/tile12_Area509_Q3.jpg
#  extracting: Data/train/0/tile12_Area510_Q3.jpg
#   inflating: Data/train/0/tile12_Area512_Q3.jpg
#  extracting: Data/train/0/tile12_Area515_Q3.jpg
#   inflating: Data/train/0/tile12_Area517_Q3.jpg
#  extracting: Data/train/0/tile12_Area519_Q3.jpg
#  extracting: Data/train/0/tile12_Area521_Q3.jpg
#  extracting: Data/train/0/tile12_Area522_Q3.jpg
#   inflating: Data/train/0/tile12_Area524_Q3.jpg
#  extracting: Data/train/0/tile12_Area526_Q3.jpg
#  extracting: Data/train/0/tile12_Area529_Q3.jpg
#   inflating: Data/train/0/tile12_Area533_Q3.jpg
#  extracting: Data/train/0/tile12_Area535_Q3.jpg
#   inflating: Data/train/0/tile12_Area536_Q3.jpg
#  extracting: Data/train/0/tile12_Area538_Q3.jpg
#  extracting: Data/train/0/tile12_Area539_Q3.jpg
#  extracting: Data/train/0/tile12_Area53_Q3.jpg
#   inflating: Data/train/0/tile12_Area540_Q3.jpg
#  extracting: Data/train/0/tile12_Area541_Q3.jpg
#  extracting: Data/train/0/tile12_Area543_Q3.jpg
#  extracting: Data/train/0/tile12_Area544_Q3.jpg
#   inflating: Data/train/0/tile12_Area545_Q3.jpg
#   inflating: Data/train/0/tile12_Area547_Q3.jpg
#   inflating: Data/train/0/tile12_Area549_Q3.jpg
#  extracting: Data/train/0/tile12_Area54_Q3.jpg
#  extracting: Data/train/0/tile12_Area550_Q3.jpg
#  extracting: Data/train/0/tile12_Area551_Q3.jpg
#   inflating: Data/train/0/tile12_Area556_Q3.jpg
#  extracting: Data/train/0/tile12_Area560_Q3.jpg
#  extracting: Data/train/0/tile12_Area573_Q3.jpg
#  extracting: Data/train/0/tile12_Area574_Q3.jpg
#  extracting: Data/train/0/tile12_Area575_Q3.jpg
#  extracting: Data/train/0/tile12_Area578_Q3.jpg
#  extracting: Data/train/0/tile12_Area57_Q3.jpg
#   inflating: Data/train/0/tile12_Area581_Q3.jpg
#  extracting: Data/train/0/tile12_Area582_Q3.jpg
#  extracting: Data/train/0/tile12_Area586_Q3.jpg
#   inflating: Data/train/0/tile12_Area587_Q3.jpg
#  extracting: Data/train/0/tile12_Area588_Q3.jpg
#  extracting: Data/train/0/tile12_Area58_Q3.jpg
#  extracting: Data/train/0/tile12_Area593_Q3.jpg
#  extracting: Data/train/0/tile12_Area594_Q3.jpg
#  extracting: Data/train/0/tile12_Area595_Q3.jpg
#  extracting: Data/train/0/tile12_Area596_Q3.jpg
#  extracting: Data/train/0/tile12_Area597_Q3.jpg
#  extracting: Data/train/0/tile12_Area59_Q3.jpg
#  extracting: Data/train/0/tile12_Area604_Q3.jpg
#   inflating: Data/train/0/tile12_Area605_Q3.jpg
#  extracting: Data/train/0/tile12_Area609_Q3.jpg
# ...
#  extracting: Data/train/1/tile8_Area365_Q3.jpg
#  extracting: Data/train/1/tile8_Area368_Q3.jpg
#  extracting: Data/train/1/tile8_Area36_Q3.jpg
#   inflating: Data/train/1/tile8_Area376_Q3.jpg
#  extracting: Data/train/1/tile8_Area378_Q3.jpg
#  extracting: Data/train/1/tile8_Area40_Q3.jpg
#  extracting: Data/train/1/tile8_Area412_Q3.jpg
#  extracting: Data/train/1/tile8_Area41_Q3.jpg
#   inflating: Data/train/1/tile8_Area420_Q3.jpg
#   inflating: Data/train/1/tile8_Area422_Q3.jpg
#  extracting: Data/train/1/tile8_Area425_Q3.jpg
#  extracting: Data/train/1/tile8_Area426_Q3.jpg
#  extracting: Data/train/1/tile8_Area429_Q3.jpg
#  extracting: Data/train/1/tile8_Area43_Q3.jpg
#   inflating: Data/train/1/tile8_Area441_Q3.jpg
#   inflating: Data/train/1/tile8_Area442_Q3.jpg
#   inflating: Data/train/1/tile8_Area445_Q3.jpg
#  extracting: Data/train/1/tile8_Area446_Q3.jpg
#   inflating: Data/train/1/tile8_Area448_Q3.jpg
#  extracting: Data/train/1/tile8_Area44_Q3.jpg
#   inflating: Data/train/1/tile8_Area450_Q3.jpg
#   inflating: Data/train/1/tile8_Area455_Q3.jpg
#  extracting: Data/train/1/tile8_Area456_Q3.jpg
#  extracting: Data/train/1/tile8_Area458_Q3.jpg
#  extracting: Data/train/1/tile8_Area478_Q3.jpg
#  extracting: Data/train/1/tile8_Area47_Q3.jpg
#  extracting: Data/train/1/tile8_Area481_Q3.jpg
#  extracting: Data/train/1/tile8_Area482_Q3.jpg
#  extracting: Data/train/1/tile8_Area484_Q3.jpg
#  extracting: Data/train/1/tile8_Area487_Q3.jpg
#  extracting: Data/train/1/tile8_Area490_Q3.jpg
#   inflating: Data/train/1/tile8_Area494_Q3.jpg
#  extracting: Data/train/1/tile8_Area498_Q3.jpg
#  extracting: Data/train/1/tile8_Area503_Q3.jpg
#  extracting: Data/train/1/tile8_Area50_Q3.jpg
#  extracting: Data/train/1/tile8_Area513_Q3.jpg
#   inflating: Data/train/1/tile8_Area514_Q3.jpg
#  extracting: Data/train/1/tile8_Area516_Q3.jpg
#  extracting: Data/train/1/tile8_Area518_Q3.jpg
#  extracting: Data/train/1/tile9_Area744_Q3.jpg
#  extracting: Data/train/1/tile9_Area74_Q3.jpg
#   inflating: Data/train/1/tile9_Area751_Q3.jpg
#  extracting: Data/train/1/tile9_Area757_Q3.jpg
#  extracting: Data/train/1/tile9_Area763_Q3.jpg
#  extracting: Data/train/1/tile9_Area770_Q3.jpg
#  extracting: Data/train/1/tile9_Area773_Q3.jpg
#  extracting: Data/train/1/tile9_Area774_Q3.jpg
#   inflating: Data/train/1/tile9_Area776_Q3.jpg
#  extracting: Data/train/1/tile9_Area778_Q3.jpg
#   inflating: Data/train/1/tile9_Area787_Q3.jpg
#  extracting: Data/train/1/tile9_Area78_Q3.jpg
#  extracting: Data/train/1/tile9_Area790_Q3.jpg
#  extracting: Data/train/1/tile9_Area802_Q3.jpg
#   inflating: Data/train/1/tile9_Area83_Q3.jpg
#  extracting: Data/train/1/tile9_Area84_Q3.jpg
#  extracting: Data/train/1/tile9_Area85_Q3.jpg
#  extracting: Data/train/1/tile9_Area88_Q3.jpg
#  extracting: Data/train/1/tile9_Area8_Q3.jpg
#   inflating: Data/train/1/tile9_Area91_Q3.jpg
#  extracting: Data/train/1/tile9_Area94_Q3.jpg
#   inflating: Data/train/1/tile9_Area98_Q3.jpg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change working directory
import os
os.chdir('/content/drive/My Drive/Banking_CW3')
# !pwd
# Out:
# /content/drive/My Drive/Banking_CW3

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # 1. Logitstic regression
# ## Identify the train/test sample at area level
#
# According to the data floder with images, we first identify the train/test sample at area level based on their filenames.

# %%
# Read the data
loans = pd.read_csv('DefaultRiskperArea.csv')

# %%
import os

train0_path = 'Data/train/0'
train1_path = 'Data/train/1'
test0_path = 'Data/test/0'
test1_path = 'Data/test/1'

# Store the image file names in a list
train_filename = [f for f in os.listdir(train0_path)] + [f for f in os.listdir(train1_path)]
test_filename = [f for f in os.listdir(test0_path)] + [f for f in os.listdir(test1_path)]

# %%
import re

# Extract areas from the file names
train_area = [re.search('Area(.*)_', fname).group(1) for fname in train_filename]
test_area = [re.search('Area(.*)_', fname).group(1) for fname in test_filename]

# %%
# Get the unique areas from two lists of areas
train_area_unq = list(set(train_area))
test_area_unq = list(set(test_area))

# %% [markdown]
# We can see from below that the intersection between these two sets are empty, which means that no areas are in both the training set and testing set.

# %%
# Check if any area is in both train and test
len(set(train_area_unq).intersection(set(test_area_unq)))
# Out:
# 0

# %% [markdown]
# Then we split the structured data into train and test by their corresponding areas.

# %%
# Split the structured data into train and test
loans_train = loans.loc[loans['Area_Number'].isin(train_area_unq)]
loans_test = loans.loc[loans['Area_Number'].isin(test_area_unq)]

# %% [markdown]
# ## Create a model
#
# Before fitting the logistic regression model, we first normalize the data using a z-transform.

# %%
# Normalize the data
from scipy.stats import zscore
loans_train_nor = pd.concat([loans_train.iloc[:,:12].apply(zscore), loans_train['BinaryDefault']], axis=1)
loans_test_nor = pd.concat([loans_test.iloc[:,:12].apply(zscore), loans_test['BinaryDefault']], axis=1)

# %% [markdown]
# Next, we fit a logistic regression model with no penalty using the training set.

# %%
from sklearn.linear_model import LogisticRegression

loans_logreg = LogisticRegression(penalty='none', # Type of penalization l1 = lasso, l2 = ridge
                                     #C = loans_logreg.C_[0], # The optimal LASSO parameter
                                     tol=0.001, # Tolerance for parameters
                                     fit_intercept=True, # Use constant?
                                     class_weight='balanced', # Weights, see below
                                     random_state=251061267, # Random seed
                                     max_iter=200, # Maximum iterations
                                     verbose=1, # Show process. 1 is yes.
                                     solver = 'newton-cg', # How to optimize.
                                     n_jobs = 1,      # Processes to use. Set to number of physical cores.
                                     warm_start = True
                                    )

# %%
loans_logreg.fit(X = loans_train_nor.iloc[:, :-1], # All rows and from the second var to end
                    y = loans_train_nor['BinaryDefault'] # The target
                   )
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=200, multi_class='auto', n_jobs=1, penalty='none',
#                    random_state=251061267, solver='newton-cg', tol=0.001,
#                    verbose=1, warm_start=True)

# %% [markdown]
# The coefficients of this model are shown below.

# %%
# Model coefficients
coef_df = pd.concat([pd.DataFrame({'column': loans_train_nor.columns[:-1]}),
                    pd.DataFrame(np.transpose(loans_logreg.coef_))],
                    axis = 1
                   )

coef_df
# Out:
#             column         0
# 0             fico -0.148200
# 1           mi_pct -0.016791
# 2        cnt_units  0.220387
# 3             cltv  5.828907
# 4              ltv -5.650831
# 5         cnt_borr  0.077678
# 6      occpy_sts_S  0.468062
# 7        channel_C -0.211828
# 8        channel_T  0.448768
# 9     prop_type_MH  0.034270
# 10    prop_type_PU -0.157366
# 11  loan_purpose_N  0.084018

# %%
# Intercept
loans_logreg1.intercept_
# Out:
# array([-0.01262056])

# %% [markdown]
# ## Model Performance
#
# After that, we apply the fitted model to the testing set and eveluate the model performance using the confusion matrix and the ROC curve.

# %%
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve
# Calculate probability
pred_class_test = loans_logreg.predict(loans_test_nor.iloc[:, :-1])
probs_test = loans_logreg.predict_proba(loans_test_nor.iloc[:, :-1])
probs_test = probs_test[:, 1]

# Calculate confusion matrix
confusion_matrix_lr = confusion_matrix(y_true = loans_test_nor['BinaryDefault'],
                    y_pred = pred_class_test)

# Turn matrix to percentages
confusion_matrix_lr = confusion_matrix_lr.astype('float') / confusion_matrix_lr.sum(axis=1)[:, np.newaxis]

# Turn to dataframe
df_cm = pd.DataFrame(
        confusion_matrix_lr, index=['good', 'bad'], columns=['good', 'bad'],
)

# Parameters of the image
figsize = (10,7)
fontsize=14

# Create image
fig = plt.figure(figsize=figsize)
heatmap = sns.heatmap(df_cm, annot=True, fmt='.4f')

# Make it nicer
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0,
                             ha='right', fontsize=fontsize)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45,
                             ha='right', fontsize=fontsize)

# Add labels
plt.ylabel('True label')
plt.xlabel('Predicted label')

# Plot!
plt.show()

# %%
# Calculate the ROC curve points
fpr, tpr, thresholds = roc_curve(loans_test_nor['BinaryDefault'], probs_test)

# Save the AUC in a variable to display it. Round it first
auc = np.round(roc_auc_score(y_true = loans_test_nor['BinaryDefault'],
                             y_score = probs_test),
              decimals = 4)

# Create and show the plot
plt.plot(fpr,tpr,label="Logistic regression, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # 2. Deep learning model
#
# ## Model training
#
# We use the *ResNet152* model to train a deep learning model using only the images.

# %%
import h5py
import PIL

# %%
from tensorflow.keras.applications import ResNet152
model_rn = ResNet152(
    include_top=False,
    weights="imagenet",
    input_shape=(224, 224, 3)
)

# %% [markdown]
# After importing the model from the tensorflow package, we add some dense layers for predictions.

# %%
from tensorflow.keras.layers import *
headModel = model_rn.output
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dropout(0.6)(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(1, activation="sigmoid")(headModel)

# %%
from tensorflow.keras import Model
model_img = Model(inputs=model_rn.input, outputs=headModel)

# %% [markdown]
# The model summary is shown below:

# %%
model_img.summary()
# Out:
# Model: "functional_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_8[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 28, 28, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_relu (Activation (None, 28, 28, 128)  0           conv3_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_add (Add)          (None, 28, 28, 512)  0           conv3_block4_out[0][0]
#                                                                  conv3_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_out (Activation)   (None, 28, 28, 512)  0           conv3_block5_add[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block5_out[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 28, 28, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_relu (Activation (None, 28, 28, 128)  0           conv3_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_add (Add)          (None, 28, 28, 512)  0           conv3_block5_out[0][0]
#                                                                  conv3_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_out (Activation)   (None, 28, 28, 512)  0           conv3_block6_add[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block6_out[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 28, 28, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_relu (Activation (None, 28, 28, 128)  0           conv3_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_add (Add)          (None, 28, 28, 512)  0           conv3_block6_out[0][0]
#                                                                  conv3_block7_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_out (Activation)   (None, 28, 28, 512)  0           conv3_block7_add[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block7_out[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 28, 28, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_relu (Activation (None, 28, 28, 128)  0           conv3_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_add (Add)          (None, 28, 28, 512)  0           conv3_block7_out[0][0]
#                                                                  conv3_block8_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_out (Activation)   (None, 28, 28, 512)  0           conv3_block8_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 256)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 14, 14, 256)  0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_add (Add)          (None, 14, 14, 1024) 0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Activation)   (None, 14, 14, 1024) 0           conv4_block7_add[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 14, 14, 256)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 14, 14, 256)  0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 14, 14, 1024) 0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Activation)   (None, 14, 14, 1024) 0           conv4_block8_add[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 14, 14, 256)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 14, 14, 256)  0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_add (Add)          (None, 14, 14, 1024) 0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Activation)   (None, 14, 14, 1024) 0           conv4_block9_add[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_bn (BatchNormal (None, 14, 14, 1024) 4096        conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_add (Add)         (None, 14, 14, 1024) 0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Activation)  (None, 14, 14, 1024) 0           conv4_block10_add[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# ...
# conv4_block33_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block33_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block33_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block33_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block33_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block33_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_3_bn (BatchNormal (None, 14, 14, 1024) 4096        conv4_block33_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_add (Add)         (None, 14, 14, 1024) 0           conv4_block32_out[0][0]
#                                                                  conv4_block33_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_out (Activation)  (None, 14, 14, 1024) 0           conv4_block33_add[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block33_out[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block34_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block34_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block34_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block34_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block34_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block34_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_3_bn (BatchNormal (None, 14, 14, 1024) 4096        conv4_block34_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_add (Add)         (None, 14, 14, 1024) 0           conv4_block33_out[0][0]
#                                                                  conv4_block34_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_out (Activation)  (None, 14, 14, 1024) 0           conv4_block34_add[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block34_out[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block35_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block35_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block35_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block35_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block35_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block35_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_3_bn (BatchNormal (None, 14, 14, 1024) 4096        conv4_block35_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_add (Add)         (None, 14, 14, 1024) 0           conv4_block34_out[0][0]
#                                                                  conv4_block35_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_out (Activation)  (None, 14, 14, 1024) 0           conv4_block35_add[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_conv (Conv2D)   (None, 14, 14, 256)  262400      conv4_block35_out[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block36_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block36_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_conv (Conv2D)   (None, 14, 14, 256)  590080      conv4_block36_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block36_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block36_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block36_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_3_bn (BatchNormal (None, 14, 14, 1024) 4096        conv4_block36_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_add (Add)         (None, 14, 14, 1024) 0           conv4_block35_out[0][0]
#                                                                  conv4_block36_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_out (Activation)  (None, 14, 14, 1024) 0           conv4_block36_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block36_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block36_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100352)       0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 256)          25690368    flatten[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 256)          0           dense_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 128)          32896       dropout_15[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128)          0           dense_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1)            129         dropout_16[0][0]
# ==================================================================================================
# Total params: 84,094,337
# Trainable params: 83,942,913
# Non-trainable params: 151,424
# __________________________________________________________________________________________________

# %%
from keras.optimizers import Adam
opt = Adam(lr=1e-5, decay=(1e-5) / 10)
model_img.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=[tf.keras.metrics.AUC()]
              )

# %% [markdown]
# Next, we prepare the images such that they can be used for training.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import preprocess_input
# prepare data augmentation configuration. One for train, one for test.
train_datagen = ImageDataGenerator(
                                  rescale=1. / 255,                         # NNets like small inputs. Rescale.
                                  shear_range=0.2,                          # Shear?
                                  zoom_range=0.2,                           # Zoom? 0.2 means from 80% to 120%
                                  horizontal_flip=True,                     # Flip horizontally?
                                  vertical_flip=True,                      # Flip vertically?
                                  preprocessing_function=preprocess_input,  # Resnet expects specific input. Set it up with this function that comes prepackaged.
                                  validation_split = 0.2                    # Create a validation cut?
                                  )

test_datagen = ImageDataGenerator(
                                  rescale=1. / 255,                       # NNets like small inputs. Rescale.
                                  shear_range=0,                          # Shear?
                                  zoom_range=0,                           # Zoom? 0.2 means from 80% to 120%
                                  horizontal_flip=False,                  # Flip horizontally?
                                  vertical_flip=False,                    # Flip vertically?
                                  preprocessing_function=preprocess_input,# Resnet expects specific input. Set it up with this function that comes prepackaged.
                                  validation_split = 0                    # No validation cut for test.
                                  )


# We will use a batch size of 64. Depends on RAM of GPU.
batch_size = 32

# Train data generator. We point to the training directory!
train_data_dir = 'Data/train'

# VGG requires 224 x 224 images.
(img_height, img_width) = (224, 224)

train_generator = train_datagen.flow_from_directory(
                                                    train_data_dir,                      # Where are the pics
                                                    target_size=(img_height, img_width), # What size should they be
                                                    batch_size=batch_size,               # Size of batch
                                                    class_mode='binary',            # Class mode, whether 'binary' or 'categorical'
                                                    subset = 'training',                 # What subset to use?
                                                    shuffle = True                       # Shuffle the data?
                                                    )

validation_generator = train_datagen.flow_from_directory(
                                                    train_data_dir,                      # Where are the pics
                                                    target_size=(img_height, img_width), # What size should they be
                                                    batch_size=batch_size,               # Size of batch
                                                    class_mode='binary',            # Class mode, whether 'binary' or 'categorical'
                                                    subset = 'validation',               # What subset to use?
                                                    shuffle = True                       # Shuffle the data?
                                                    )

# Test data generator.
test_data_dir = 'Data/test'
test_generator = test_datagen.flow_from_directory(
                                                  test_data_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=1,
                                                  class_mode='binary',
                                                  shuffle = False
                                                  )
# Out:
# Found 3988 images belonging to 2 classes.
# Found 996 images belonging to 2 classes.
# Found 2142 images belonging to 2 classes.

# %% [markdown]
# Then we can train the model with prepared data.

# %%
# Number of epochs
epochs = 10

# Train!
model_img.fit(
            train_generator,
            epochs=epochs,
            validation_data=validation_generator,
            initial_epoch = 0,
            steps_per_epoch = 62*2, # Train cases / batch size = 62
            validation_steps = 15*2 # Validation cases / batch_size = 15.
          )
# Out:
# Epoch 1/10
# 124/124 [==============================] - 150s 1s/step - loss: 1.1207 - auc_11: 0.5249 - val_loss: 0.9667 - val_auc_11: 0.5140
# Epoch 2/10
# 124/124 [==============================] - 150s 1s/step - loss: 0.7903 - auc_11: 0.5770 - val_loss: 1.3337 - val_auc_11: 0.5121
# Epoch 3/10
# 124/124 [==============================] - 152s 1s/step - loss: 0.7002 - auc_11: 0.6026 - val_loss: 0.7583 - val_auc_11: 0.5146
# Epoch 4/10
# 124/124 [==============================] - 152s 1s/step - loss: 0.6446 - auc_11: 0.6472 - val_loss: 0.9179 - val_auc_11: 0.5018
# Epoch 5/10
# 124/124 [==============================] - 152s 1s/step - loss: 0.6255 - auc_11: 0.6632 - val_loss: 0.9166 - val_auc_11: 0.5385
# Epoch 6/10
# 124/124 [==============================] - 152s 1s/step - loss: 0.6145 - auc_11: 0.6824 - val_loss: 0.7192 - val_auc_11: 0.5293
# Epoch 7/10
# 124/124 [==============================] - 153s 1s/step - loss: 0.5760 - auc_11: 0.7304 - val_loss: 0.6867 - val_auc_11: 0.5666
# Epoch 8/10
# 124/124 [==============================] - 154s 1s/step - loss: 0.5718 - auc_11: 0.7360 - val_loss: 0.6723 - val_auc_11: 0.5858
# Epoch 9/10
# 124/124 [==============================] - 152s 1s/step - loss: 0.5468 - auc_11: 0.7695 - val_loss: 0.6542 - val_auc_11: 0.6163
# Epoch 10/10
# 124/124 [==============================] - 152s 1s/step - loss: 0.5458 - auc_11: 0.7670 - val_loss: 0.6206 - val_auc_11: 0.6724

# %%
loss = model_img.history.history['metric']
val_loss = model_img.history.history['val_metric']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Applying the model
# Next, we use the trained model to make predictions on the testing set.

# %%
# Applying to the test set with a generator.
test_generator.reset()

# Get probabilities
output = model_img.predict(test_generator)
labels = test_generator.classes

# %%
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve
# Calculate the ROC curve points
fpr, tpr, thresholds = roc_curve(labels, output[:,0])

# Save the AUC in a variable to display it. Round it first
auc = np.round(roc_auc_score(y_true = labels,
                             y_score = output[:,0]),
              decimals = 4)

# Create and show the plot
plt.plot(fpr,tpr,label="ResNet152, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
# Save the model
model_img.save('Resnet152_a.h5')

# %%
model_img = keras.models.load_model('Resnet101.h5')

# %% [markdown]
# # 3. Multimodal Learning
# ## Combining the structured data with the path of image data
#
# Before constructing the multimodal deep learning model, we first need to combine the structured inputs and the path of images into one dataframe.

# %%
loans = pd.read_csv('DefaultRiskperArea.csv')

# %%
train0_path = 'Data/train/0'
train1_path = 'Data/train/1'
test0_path = 'Data/test/0'
test1_path = 'Data/test/1'

# Get the path of all the images
train_filename1 = [os.path.join(train0_path, f) for f in os.listdir(train0_path)] + [os.path.join(train1_path, f) for f in os.listdir(train1_path)]
test_filename1 = [os.path.join(test0_path, f) for f in os.listdir(test0_path)] + [os.path.join(test1_path, f) for f in os.listdir(test1_path)]
filename = train_filename1 + test_filename1

# %%
# Match the path with structured data according to the area number
import re
loans['path'] = [[fname for fname in filename if (re.search('Area(.*)_', fname).group(1)+ '.0') == str(area_num)] for area_num in loans.Area_Number]

# %%
# Explode the path such that each row has only one path
loans = pd.DataFrame({
          col:np.repeat(loans[col].values, loans['path'].str.len())
          for col in loans.columns.difference(['path'])
      }).assign(**{'path':np.concatenate(loans['path'].values)})[loans.columns.tolist()]

# %% [markdown]
# Similarly, we split the data into train and test according to the area number.

# %%
# Split the structured data into train and test
loans_train = loans.loc[loans['Area_Number'].isin(train_area_unq)]
loans_test = loans.loc[loans['Area_Number'].isin(test_area_unq)]

# %% [markdown]
# Then we normalize the data into the interval [0, 1] since we need to have small inputs for the neural network.

# %%
from sklearn.preprocessing import MinMaxScaler

Scaler = MinMaxScaler()
Scaler.fit(loans_train.iloc[:,:12])
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
loans_train.iloc[:,:12] = Scaler.transform(loans_train.iloc[:,:12])
loans_test.iloc[:,:12] = Scaler.transform(loans_test.iloc[:,:12])

# %%
loans_train.drop(['Area_Number'], axis=1, inplace=True)
loans_test.drop(['Area_Number'], axis=1, inplace=True)

# %% [markdown]
# ## Construct the model
#
# After that, we can construct the multimodal deep learning model as follow.

# %%
# Parameters
ImageSize = (224,224)
BatchSize = 32

import tensorflow as tf
from tensorflow.keras.layers import *
image_input = tf.keras.Input(shape=ImageSize + (3,), name = 'image_input')

# Load an empty ResNet101
from tensorflow.keras.applications import ResNet152
rn_input = ResNet152(weights='imagenet', include_top=False)

# Use the model API to attach it to our input layer.
ImageClassifier = rn_input(image_input)

# Add a Flatten layer with the model API.
ImageClassifier = Flatten()(ImageClassifier)

# Now we create the structured data layer.
predictive_features = 12
features_input  = keras.Input(shape=(predictive_features,), name="structured_data")
Structured =  Dense(8, activation = 'relu' )(features_input) # Add one processing layer
Structured =  Dropout(0.5)(Structured)   # Dropout after  Dense
Structured =  Dense(4, activation = 'relu' )(Structured) # Add one processing layer
Structured =  Dropout(0.5)(Structured)   # Dropout after  Dense

# Merge all available features into a single large vector via concatenation
merged = concatenate([ImageClassifier, Structured])

# Add a few prediction layers
merged = Dense(512, activation='relu')(merged)
merged = Dropout(0.5)(merged)
merged = Dense(128, activation='relu')(merged)
merged = Dropout(0.5)(merged)

loans_multi = Dense(1, activation='sigmoid', name="loans_multi")(merged)

# Instantiate an end-to-end model predicting house_prices
multimodal_model = keras.Model(inputs=[image_input, features_input],
                               outputs=[loans_multi])

# %%
multimodal_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# structured_data (InputLayer)    [(None, 12)]         0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            104         structured_data[0][0]
# __________________________________________________________________________________________________
# image_input (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8)            0           dense[0][0]
# __________________________________________________________________________________________________
# resnet152 (Functional)          (None, None, None, 2 58370944    image_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            36          dropout[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 100352)       0           resnet152[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 4)            0           dense_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 100356)       0           flatten_1[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          51382784    concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          65664       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# loans_multi (Dense)             (None, 1)            129         dropout_3[0][0]
# ==================================================================================================
# Total params: 109,819,661
# Trainable params: 109,668,237
# Non-trainable params: 151,424
# __________________________________________________________________________________________________

# %%
from keras.optimizers import Adam
opt = Adam(lr=1e-5, decay=(1e-5) / 10)
from tensorflow.keras import optimizers
multimodal_model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=[tf.keras.metrics.AUC()]
              )

# %% [markdown]
# The model we construct can be visualized in the following plot.

# %%
import pydot as pyd
from tensorflow.keras.utils import plot_model

#Visualize Model
plot_model(
          multimodal_model, to_file='model.png', show_shapes=False, show_layer_names=True,
          rankdir='TB', expand_nested=False, dpi=96
          )

# %% [markdown]
# ## Model fitting

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import preprocess_input
# prepare data augmentation configuration. One for train, one for test.
train_datagen = ImageDataGenerator(
                                  rescale=1. / 255,                         # NNets like small inputs. Rescale.
                                  shear_range=0.2,                          # Shear?
                                  zoom_range=0.2,                           # Zoom? 0.2 means from 80% to 120%
                                  horizontal_flip=True,                     # Flip horizontally?
                                  vertical_flip=True,                      # Flip vertically?
                                  preprocessing_function=preprocess_input,  # Resnet expects specific input. Set it up with this function that comes prepackaged.
                                  validation_split = 0.2                    # Create a validation cut?
                                  )

test_datagen = ImageDataGenerator(
                                  rescale=1. / 255,                       # NNets like small inputs. Rescale.
                                  shear_range=0,                          # Shear?
                                  zoom_range=0,                           # Zoom? 0.2 means from 80% to 120%
                                  horizontal_flip=False,                  # Flip horizontally?
                                  vertical_flip=False,                    # Flip vertically?
                                  preprocessing_function=preprocess_input,# Resnet expects specific input. Set it up with this function that comes prepackaged.
                                  validation_split = 0                    # No validation cut for test.
                                  )

# %%
# Define parameters

target_size = (224, 224)
batch_size = 32

# What are the useful columns? Note the position of the target.
pred_cols = np.r_[0:13]

# We only modify the generators. Note the y vector.
train_generator = train_datagen.flow_from_dataframe(loans_train,
                                                    directory='.',
                                                    x_col='path',
                                                    y_col=loans_train.columns[pred_cols],
                                                    target_size=target_size,
                                                    batch_size=batch_size,
                                                    shuffle=True,
                                                    class_mode='raw',
                                                    subset='training',
                                                    interpolation="bilinear"
                                                   )

validation_generator = train_datagen.flow_from_dataframe(loans_train,
                                                    directory='.',
                                                    x_col='path',
                                                    y_col=loans_train.columns[pred_cols],
                                                    target_size=target_size,
                                                    batch_size=batch_size,
                                                    shuffle=True,
                                                    class_mode='raw',
                                                    subset='validation',
                                                    interpolation="bilinear"
                                                   )

test_generator = train_datagen.flow_from_dataframe(loans_test,
                                                    directory='.',
                                                    x_col='path',
                                                    y_col=loans_test.columns[pred_cols],
                                                    target_size=target_size,
                                                    batch_size=batch_size,
                                                    shuffle=False,
                                                    class_mode='raw',
                                                    subset='training',
                                                    interpolation="bilinear"
                                                   )

# Define combined generator
def train_generator_func():
    count = 0

    while True:
        if  count == len(loans_train.index):
            train_generator.reset()
            break
        count += 1
        data = train_generator.next()

        # Let's identify where is what.
        target_location = 12
        predictive_columns = np.r_[0:12]

        # Now we reshape everything. First the images.
        imgs = data[0]
        # Now we need to extract which ones are the predictive variables.
        cols = data[1][:, predictive_columns]
        # Finally we need the targets.
        targets = data[1][:, target_location]
        yield [imgs, cols], targets


def validation_generator_func():
    count = 0
    while True:
        if count == len(loans_train.index):
            validation_generator.reset()
            break
        count += 1
        data = validation_generator.next()

        # Let's identify where is what.
        target_location = 12
        predictive_columns = np.r_[0:12]

        # Now we reshape everything. First the images.
        imgs = data[0]
        # Now we need to extract which ones are the predictive variables.
        cols = data[1][:, predictive_columns]
        # Finally we need the targets.
        targets = data[1][:, target_location]
        yield [imgs, cols], targets


def test_generator_func():
    count = 0
    test_generator.reset()
    while True:
        if count == len(loans_test.index):
            test_generator.reset()
            break
        count += 1
        data = test_generator.next()

        # Let's identify where is what.
        target_location = 12
        predictive_columns = np.r_[0:12]

        # Now we reshape everything. First the images.
        imgs = data[0]
        # Now we need to extract which ones are the predictive variables.
        cols = data[1][:, predictive_columns]
        # Finally we need the targets.
        targets = data[1][:, target_location]
        yield [imgs, cols], targets
# Out:
# Found 3988 validated image filenames.
# Found 996 validated image filenames.
# Found 1714 validated image filenames.

# %%
steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = validation_generator.samples // validation_generator.batch_size
multimodal_model.fit(train_generator_func(),
                      epochs=10,
                      initial_epoch = 0,
                      steps_per_epoch=steps_per_epoch,
                      validation_data=validation_generator_func(),
                      validation_steps=validation_steps
                     )

# %% [markdown]
# ## Applying to the testing set

# %%
# Calculate outputs in test set
STEP_SIZE_TEST = test_generator.n//test_generator.batch_size

loans_result = multimodal_model.predict(test_generator_func(),
                                    steps=STEP_SIZE_TEST+1,
                                    verbose=1)
# Out:
# 54/54 [==============================] - 49s 898ms/step

# %%
labels = test_generator.labels[:,12]
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve
# Calculate the ROC curve points
fpr, tpr, thresholds = roc_curve(labels, loans_result)

# Save the AUC in a variable to display it. Round it first
auc = np.round(roc_auc_score(y_true = labels,
                             y_score = loans_result),
              decimals = 4)

# Create and show the plot
plt.plot(fpr,tpr,label="Multimodal, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
# Save the model
multimodal_model.save('multimodal.h5')
